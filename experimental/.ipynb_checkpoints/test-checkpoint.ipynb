# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import hyperspy.api as hs

# %%
s = hs.load("data_SnO2/001 direction.dm4")

# %%
s.plot()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
s.axes_manager.gui()
